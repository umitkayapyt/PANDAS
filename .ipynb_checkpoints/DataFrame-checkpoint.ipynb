# %%
import pandas as pd

# %%
veri={"isim":["Ali","Can","Efe","Ayşe","Buse","Alp","Nur"],
     "puan":[90,80,85,75,95,60,60],
     "spor":["Futbol","Güreş","Kayak","Yüzme","Tenis","Karate","Sörf"],
     "cinsiyet":["E","E","E","K","K","E","K"]}
df=pd.DataFrame(veri)
df
# Out:
#    isim  puan    spor cinsiyet
# 0   Ali    90  Futbol        E
# 1   Can    80   Güreş        E
# 2   Efe    85   Kayak        E
# 3  Ayşe    75   Yüzme        K
# 4  Buse    95   Tenis        K
# 5   Alp    60  Karate        E
# 6   Nur    60    Sörf        K

# %%
df.head(7)
# Out:
#    isim  puan    spor cinsiyet
# 0   Ali    90  Futbol        E
# 1   Can    80   Güreş        E
# 2   Efe    85   Kayak        E
# 3  Ayşe    75   Yüzme        K
# 4  Buse    95   Tenis        K
# 5   Alp    60  Karate        E
# 6   Nur    60    Sörf        K

# %%
df.tail()
# Out:
#    isim  puan    spor cinsiyet
# 2   Efe    85   Kayak        E
# 3  Ayşe    75   Yüzme        K
# 4  Buse    95   Tenis        K
# 5   Alp    60  Karate        E
# 6   Nur    60    Sörf        K

# %%
df=pd.DataFrame(veri,columns=["isim","sport","cinsiyet","puan"])

# %%
df
# Out:
#    isim sport cinsiyet  puan
# 0   Ali   NaN        E    90
# 1   Can   NaN        E    80
# 2   Efe   NaN        E    85
# 3  Ayşe   NaN        K    75
# 4  Buse   NaN        K    95
# 5   Alp   NaN        E    60
# 6   Nur   NaN        K    60

# %%
df=pd.DataFrame(veri,columns=["isim","sport","cinsiyet","puan","yaş"])

# %%
df
# Out:
#    isim sport cinsiyet  puan  yaş
# 0   Ali   NaN        E    90  NaN
# 1   Can   NaN        E    80  NaN
# 2   Efe   NaN        E    85  NaN
# 3  Ayşe   NaN        K    75  NaN
# 4  Buse   NaN        K    95  NaN
# 5   Alp   NaN        E    60  NaN
# 6   Nur   NaN        K    60  NaN

# %%
df=pd.DataFrame(veri,columns=["isim","sport","cinsiyet","puan","yaş"],
               index=["bir","iki","üç","dör","beş","altı","yedi"])

# %%
df
# Out:
#       isim sport cinsiyet  puan  yaş
# bir    Ali   NaN        E    90  NaN
# iki    Can   NaN        E    80  NaN
# üç     Efe   NaN        E    85  NaN
# dör   Ayşe   NaN        K    75  NaN
# beş   Buse   NaN        K    95  NaN
# altı   Alp   NaN        E    60  NaN
# yedi   Nur   NaN        K    60  NaN

# %%
df["sport","isim"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('sport', 'isim')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-25-6f22bfbc0394> in <module>
# ...

# %%
sütunlarım=["isim","sport"]
df[sütunlarım]
# Out:
#       isim sport
# bir    Ali   NaN
# iki    Can   NaN
# üç     Efe   NaN
# dör   Ayşe   NaN
# beş   Buse   NaN
# altı   Alp   NaN
# yedi   Nur   NaN

# %%
df.sport
# Out:
# bir     NaN
# iki     NaN
# üç      NaN
# dör     NaN
# beş     NaN
# altı    NaN
# yedi    NaN
# Name: sport, dtype: object

# %%
df["sport"]
# Out:
# bir     NaN
# iki     NaN
# üç      NaN
# dör     NaN
# beş     NaN
# altı    NaN
# yedi    NaN
# Name: sport, dtype: object

# %%
df.loc[["bir"]]
# Out:
#     isim sport cinsiyet  puan  yaş
# bir  Ali   NaN        E    90  NaN

# %%
df["yaş"]=18

# %%
df
# Out:
#       isim sport cinsiyet  puan  yaş
# bir    Ali   NaN        E    90   18
# iki    Can   NaN        E    80   18
# üç     Efe   NaN        E    85   18
# dör   Ayşe   NaN        K    75   18
# beş   Buse   NaN        K    95   18
# altı   Alp   NaN        E    60   18
# yedi   Nur   NaN        K    60   18

# %%
df.loc[["bir"],["cinsiyet"]]=19

# %%
df
# Out:
#       isim sport cinsiyet  puan  yaş
# bir    Ali   NaN       19    90   19
# iki    Can   NaN        E    80   18
# üç     Efe   NaN        E    85   18
# dör   Ayşe   NaN        K    75   18
# beş   Buse   NaN        K    95   18
# altı   Alp   NaN        E    60   18
# yedi   Nur   NaN        K    60   18

# %% [raw]
# değer=

# %%
değer=[17,18,19,20,21,22,23]

# %%
df["yaş"]=değer

# %%
df
# Out:
#       isim sport cinsiyet  puan  yaş
# bir    Ali   NaN       19    90   17
# iki    Can   NaN        E    80   18
# üç     Efe   NaN        E    85   19
# dör   Ayşe   NaN        K    75   20
# beş   Buse   NaN        K    95   21
# altı   Alp   NaN        E    60   22
# yedi   Nur   NaN        K    60   23

# %%
df["geçti"]
# Out:
# bir      True
# iki      True
# üç       True
# dör      True
# beş      True
# altı    False
# yedi    False
# Name: geçti, dtype: bool

# %%
df
# Out:
#       isim sport cinsiyet  puan  yaş  geçti
# bir    Ali   NaN       19    90   17   True
# iki    Can   NaN        E    80   18   True
# üç     Efe   NaN        E    85   19   True
# dör   Ayşe   NaN        K    75   20   True
# beş   Buse   NaN        K    95   21   True
# altı   Alp   NaN        E    60   22  False
# yedi   Nur   NaN        K    60   23  False

# %%
df
# Out:
#       isim sport cinsiyet  puan  yaş  geçti
# bir    Ali   NaN       19    90   17   True
# iki    Can   NaN        E    80   18   True
# üç     Efe   NaN        E    85   19   True
# dör   Ayşe   NaN        K    75   20   True
# beş   Buse   NaN        K    95   21   True
# altı   Alp   NaN        E    60   22  False
# yedi   Nur   NaN        K    60   23  False

# %%
del df["geçti"]

# %%
df
# Out:
#       isim sport cinsiyet  puan  yaş
# bir    Ali   NaN       19    90   17
# iki    Can   NaN        E    80   18
# üç     Efe   NaN        E    85   19
# dör   Ayşe   NaN        K    75   20
# beş   Buse   NaN        K    95   21
# altı   Alp   NaN        E    60   22
# yedi   Nur   NaN        K    60   23

# %%
değer=[1,2,3,4,5,6,7]
df["geçti"]=değer
df
# Out:
#       isim sport cinsiyet  puan  yaş  geçti
# bir    Ali   NaN       19    90   17      1
# iki    Can   NaN        E    80   18      2
# üç     Efe   NaN        E    85   19      3
# dör   Ayşe   NaN        K    75   20      4
# beş   Buse   NaN        K    95   21      5
# altı   Alp   NaN        E    60   22      6
# yedi   Nur   NaN        K    60   23      7

# %%
notlar={"Mat":{"Ali":80,"Veli":70,"Deli":60},
       "Fizik":{"Ali":70,"Veli":60,"Deli":50}}
puan=pd.DataFrame(notlar)
puan
# Out:
#       Mat  Fizik
# Ali    80     70
# Veli   70     60
# Deli   60     50

# %%
puan["Bio"]=[70,60,50]
puan
# Out:
#       Mat  Fizik  Bio
# Ali    80     70   70
# Veli   70     60   60
# Deli   60     50   50

# %%
puan.T
# Out:
#        Ali  Veli  Deli
# Mat     80    70    60
# Fizik   70    60    50
# Bio     70    60    50

# %%
puan.index.name="isim"
puan.columns.name="ders"
puan
# Out:
# ders  Mat  Fizik  Bio
# isim
# Ali    80     70   70
# Veli   70     60   60
# Deli   60     50   50

# %%
puan.values
# Out:
# array([[80, 70, 70],
#        [70, 60, 60],
#        [60, 50, 50]], dtype=int64)

# %%
indekz=puan.index

# %%
indekz[1]="sd"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-71-571f8695fff6> in <module>
# ----> 1 indekz[1]="sd"
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in __setitem__(self, key, value)
#    4275     @final
#    4276     def __setitem__(self, key, value):
# -> 4277         raise TypeError("Index does not support mutable operations")
#    4278
#    4279     def __getitem__(self, key):
#
# TypeError: Index does not support mutable operations

# %%
puan[1]="ada"

# %%
puan
# Out:
# ders  Mat  Fizik  Bio    1
# isim
# Ali    80     70   70  ada
# Veli   70     60   60  ada
# Deli   60     50   50  ada

# %%
puan.index[1]="sşld"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-74-b87b85110d48> in <module>
# ----> 1 puan.index[1]="sşld"
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in __setitem__(self, key, value)
#    4275     @final
#    4276     def __setitem__(self, key, value):
# -> 4277         raise TypeError("Index does not support mutable operations")
#    4278
#    4279     def __getitem__(self, key):
#
# TypeError: Index does not support mutable operations
