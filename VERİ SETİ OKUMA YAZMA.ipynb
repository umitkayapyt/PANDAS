# %%
import pandas as pd

# %%
eksik_veri={"sepal_width":[-3.5,"Iris-setosa"],"petal_length":["NA.4","1.n.a"]}
df=pd.read_table("iriss.txt", sep=",",na_values=eksik_veri,header=None, 
                 names=["sepal_length","sepal_width","petal_length","petal_width","species"])
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          NaN           1.4          0.2     Iris-setosa
# 1             NaN          3.0           NaN          0.2     Iris-setosa
# 2             4.7          3.2           NaN          0.2     Iris-setosa
# 3             4.6          NaN           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
import sys
df.to_csv(sys.stdout,sep="|",na_rep="NUL",index=False, columns=["sepal_length","species"])
# Out:
# sepal_length|species
# 5.1|Iris-setosa
# NUL|Iris-setosa
# 4.7|Iris-setosa
# 4.6|Iris-setosa
# 5.0|Iris-setosa
# 5.4|Iris-setosa
# 4.6|Iris-setosa
# 5.0|Iris-setosa
# 4.4|Iris-setosa
# 4.9|Iris-setosa
# 5.4|Iris-setosa
# 4.8|Iris-setosa
# 4.8|Iris-setosa
# 4.3|Iris-setosa
# 5.8|Iris-setosa
# 5.7|Iris-setosa
# 5.4|Iris-setosa
# 5.1|Iris-setosa
# 5.7|Iris-setosa
# 5.1|Iris-setosa
# 5.4|Iris-setosa
# 5.1|Iris-setosa
# 4.6|Iris-setosa
# 5.1|Iris-setosa
# 4.8|Iris-setosa
# 5.0|Iris-setosa
# 5.0|Iris-setosa
# 5.2|Iris-setosa
# 5.2|Iris-setosa
# 4.7|Iris-setosa
# 4.8|Iris-setosa
# 5.4|Iris-setosa
# 5.2|Iris-setosa
# 5.5|Iris-setosa
# 4.9|Iris-setosa
# 5.0|Iris-setosa
# 5.5|Iris-setosa
# 4.9|Iris-setosa
# 4.4|Iris-setosa
# 5.1|Iris-setosa
# 5.0|Iris-setosa
# 4.5|Iris-setosa
# 4.4|Iris-setosa
# 5.0|Iris-setosa
# 5.1|Iris-setosa
# 4.8|Iris-setosa
# 5.1|Iris-setosa
# 4.6|Iris-setosa
# 5.3|Iris-setosa
# 5.0|Iris-setosa
# 7.0|Iris-versicolor
# 6.4|Iris-versicolor
# 6.9|Iris-versicolor
# ...

# %%
df5

# %%
pd.read_excel("C:/Users/Ümit/Desktop/İNDİRELENLER/88k_Puantaj_ACIBADEM_ALTUN196176ZADE (1).xls",header=None,names=["A-Z"])
# Out:
#                                                                                                                                                                                                       A  \
# NaN NaN           NaN            NaN NaN NaN                  NaN                 NaN                NaN                       NaN                                                                  NaN
#     Hazırlayan    NaN            NaN NaN Tarih                İŞYERİ              TOPLAM ÇALIŞAN     İLÇE                      NaN                                                                  NaN
#     DAMLA GÜNEŞ   NaN            NaN NaN 2021-05-01 00:00:00  NaN                 5                  NaN                       NaN                                                                  NaN
# ...
