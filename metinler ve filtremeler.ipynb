# %%
import pandas as pd ; import numpy as np

# %%
veri=["ali","Berk","DENİz",np.nan,"zEYNEP"]

# %%
isim=pd.Series(veri)

# %%
isim.str.len()
# Out:
# 0    3.0
# 1    4.0
# 2    5.0
# 3    NaN
# 4    6.0
# dtype: float64

# %%
df=pd.DataFrame(np.random.randn(3,2),
               columns=["Sütun A","Sütun B"],
               index=range(3))
df
# Out:
#     Sütun A   Sütun B
# 0 -0.623633 -1.210049
# 1  1.431494  0.299208
# 2  1.117780  0.361256

# %%
df.columns
# Out:
# Index(['Sütun A', 'Sütun B'], dtype='object')

# %%
df.columns.str.upper()
# Out:
# Index(['SÜTUN A', 'SÜTUN B'], dtype='object')

# %%
df.columns.str.capitalize()
# Out:
# Index(['Sütun a', 'Sütun b'], dtype='object')

# %%
df.columns.str.lower()
# Out:
# Index(['sütun a', 'sütun b'], dtype='object')

# %%
df.columns.str.len()
# Out:
# Int64Index([7, 7], dtype='int64')

# %%
df.columns.str.lower().str.replace(" ","_")
# Out:
# Index(['sütun_a', 'sütun_b'], dtype='object')

# %%
s=pd.Series(["a_b_c","c_d_e",np.nan,"f_g_h"])
s
# Out:
# 0    a_b_c
# 1    c_d_e
# 2      NaN
# 3    f_g_h
# dtype: object

# %%
s.str.split("_").str.get(2)
# Out:
# 0      c
# 1      e
# 2    NaN
# 3      h
# dtype: object

# %%
s.str.split("_").str[2]
# Out:
# 0      c
# 1      e
# 2    NaN
# 3      h
# dtype: object

# %%
    s.str.split("_",expand=True,n=1)
# Out:
#      0    1
# 0    a  b_c
# 1    c  d_e
# 2  NaN  NaN
# 3    f  g_h

# %%
para=pd.Series(["15","-$20","30000"])
para
# Out:
# 0       15
# 1     -$20
# 2    30000
# dtype: object

# %%
para.str.replace("-\$","")
# Out:
# <ipython-input-33-b15963b2c6d3>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   para.str.replace("-\$","")
# 0       15
# 1       20
# 2    30000
# dtype: object

# %%
film
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
film.title.str.upper()
# Out:
# 0                             THE SHAWSHANK REDEMPTION
# 1                                        THE GODFATHER
# 2                               THE GODFATHER: PART II
# 3                                      THE DARK KNIGHT
# 4                                         PULP FICTION
#                             ...
# 974                                            TOOTSIE
# 975                        BACK TO THE FUTURE PART III
# 976    MASTER AND COMMANDER: THE FAR SIDE OF THE WORLD
# 977                                        POLTERGEIST
# 978                                        WALL STREET
# Name: title, Length: 979, dtype: object

# %%
film.columns=film.columns.str.capitalize()

# %%
film.columns
# Out:
# Index(['Star_rating', 'Title', 'Content_rating', 'Genre', 'Duration',
#        'Actors_list'],
#       dtype='object')

# %%
film[film.Actors_list.str.contains("Brad Pitt")]
# Out:
#      Star_rating                                              Title  \
# 9            8.9                                         Fight Club
# 24           8.7                                              Se7en
# 106          8.3                                            Snatch.
# 114          8.3                               Inglourious Basterds
# 264          8.1                                     Twelve Monkeys
# 508          7.8                The Curious Case of Benjamin Button
# 577          7.8                                     Ocean's Eleven
# 683          7.7                                               Fury
# 776          7.6                                          Moneyball
# 779          7.6  Interview with the Vampire: The Vampire Chroni...
# 807          7.6  The Assassination of Jesse James by the Coward...
# 826          7.5                                           Sleepers
# 877          7.5                                Legends of the Fall
# ...

# %%
film.Actors_list.str.replace("[\[\]]","")
# Out:
# <ipython-input-46-b8053ecef64b>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   film.Actors_list.str.replace("[\[\]]","")
# 0       u'Tim Robbins', u'Morgan Freeman', u'Bob Gunton'
# 1          u'Marlon Brando', u'Al Pacino', u'James Caan'
# 2      u'Al Pacino', u'Robert De Niro', u'Robert Duvall'
# 3      u'Christian Bale', u'Heath Ledger', u'Aaron Ec...
# 4      u'John Travolta', u'Uma Thurman', u'Samuel L. ...
#                              ...
# 974    u'Dustin Hoffman', u'Jessica Lange', u'Teri Garr'
# 975    u'Michael J. Fox', u'Christopher Lloyd', u'Mar...
# 976     u'Russell Crowe', u'Paul Bettany', u'Billy Boyd'
# 977    u'JoBeth Williams', u"Heather O'Rourke", u'Cra...
# 978    u'Charlie Sheen', u'Michael Douglas', u'Tamara...
# Name: Actors_list, Length: 979, dtype: object

# %%
film["Title"]
# Out:
# 0                             The Shawshank Redemption
# 1                                        The Godfather
# 2                               The Godfather: Part II
# 3                                      The Dark Knight
# 4                                         Pulp Fiction
#                             ...
# 974                                            Tootsie
# 975                        Back to the Future Part III
# 976    Master and Commander: The Far Side of the World
# 977                                        Poltergeist
# 978                                        Wall Street
# Name: Title, Length: 979, dtype: object

# %%
film[["Title","Genre"]]
# Out:
#                                                Title      Genre
# 0                           The Shawshank Redemption      Crime
# 1                                      The Godfather      Crime
# 2                             The Godfather: Part II      Crime
# 3                                    The Dark Knight     Action
# 4                                       Pulp Fiction      Crime
# ..                                               ...        ...
# 974                                          Tootsie     Comedy
# 975                      Back to the Future Part III  Adventure
# 976  Master and Commander: The Far Side of the World     Action
# 977                                      Poltergeist     Horror
# 978                                      Wall Street      Crime
#
# [979 rows x 2 columns]

# %%
film.loc[0,]
# Out:
# Star_rating                                                     9.3
# Title                                      The Shawshank Redemption
# Content_rating                                                    R
# Genre                                                         Crime
# Duration                                                        142
# Actors_list       [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# Name: 0, dtype: object

# %%
film.loc[[0,2,4],]
# Out:
#    Star_rating                     Title Content_rating  Genre  Duration  \
# 0          9.3  The Shawshank Redemption              R  Crime       142
# 2          9.1    The Godfather: Part II              R  Crime       200
# 4          8.9              Pulp Fiction              R  Crime       154
#
#                                          Actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
film.loc[0:5,"Title"]
# Out:
# 0    The Shawshank Redemption
# 1               The Godfather
# 2      The Godfather: Part II
# 3             The Dark Knight
# 4                Pulp Fiction
# 5                12 Angry Men
# Name: Title, dtype: object

# %%
film.loc[0:5,["Title","Genre"]]
# Out:
#                       Title   Genre
# 0  The Shawshank Redemption   Crime
# 1             The Godfather   Crime
# 2    The Godfather: Part II   Crime
# 3           The Dark Knight  Action
# 4              Pulp Fiction   Crime
# 5              12 Angry Men   Drama

# %%
film.loc[:,"Title":"Genre"]
# Out:
#                                                Title Content_rating      Genre
# 0                           The Shawshank Redemption              R      Crime
# 1                                      The Godfather              R      Crime
# 2                             The Godfather: Part II              R      Crime
# 3                                    The Dark Knight          PG-13     Action
# 4                                       Pulp Fiction              R      Crime
# ..                                               ...            ...        ...
# 974                                          Tootsie             PG     Comedy
# 975                      Back to the Future Part III             PG  Adventure
# 976  Master and Commander: The Far Side of the World          PG-13     Action
# 977                                      Poltergeist             PG     Horror
# 978                                      Wall Street              R      Crime
#
# [979 rows x 3 columns]

# %%
film.loc[film.Genre=="Crime",]
# Out:
#      Star_rating                     Title Content_rating  Genre  Duration  \
# 0            9.3  The Shawshank Redemption              R  Crime       142
# 1            9.2             The Godfather              R  Crime       175
# 2            9.1    The Godfather: Part II              R  Crime       200
# 4            8.9              Pulp Fiction              R  Crime       154
# 21           8.7               City of God              R  Crime       130
# ..           ...                       ...            ...    ...       ...
# 927          7.5                     Brick              R  Crime       110
# 931          7.4              Mean Streets              R  Crime       112
# 950          7.4                     Bound              R  Crime       108
# 969          7.4       Law Abiding Citizen              R  Crime       109
# 978          7.4               Wall Street              R  Crime       126
#
#                                            Actors_list
# ...

# %%
film.loc[film.Genre=="Crime","Title":"Duration"]
# Out:
#                         Title Content_rating  Genre  Duration
# 0    The Shawshank Redemption              R  Crime       142
# 1               The Godfather              R  Crime       175
# 2      The Godfather: Part II              R  Crime       200
# 4                Pulp Fiction              R  Crime       154
# 21                City of God              R  Crime       130
# ..                        ...            ...    ...       ...
# 927                     Brick              R  Crime       110
# 931              Mean Streets              R  Crime       112
# 950                     Bound              R  Crime       108
# 969       Law Abiding Citizen              R  Crime       109
# 978               Wall Street              R  Crime       126
#
# [124 rows x 4 columns]

# %%
film.iloc[:,0].head()
# Out:
# 0    9.3
# 1    9.2
# 2    9.1
# 3    9.0
# 4    8.9
# Name: Star_rating, dtype: float64

# %%
film.columns
# Out:
# Index(['Star_rating', 'Title', 'Content_rating', 'Genre', 'Duration',
#        'Actors_list'],
#       dtype='object')

# %%
film.iloc[:,[0,3]]
# Out:
#      Star_rating      Genre
# 0            9.3      Crime
# 1            9.2      Crime
# 2            9.1      Crime
# 3            9.0     Action
# 4            8.9      Crime
# ..           ...        ...
# 974          7.4     Comedy
# 975          7.4  Adventure
# 976          7.4     Action
# 977          7.4     Horror
# 978          7.4      Crime
#
# [979 rows x 2 columns]

# %%
film.iloc[:,0:3]
# Out:
#      Star_rating                                            Title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     Content_rating
# 0                R
# 1                R
# 2                R
# 3            PG-13
# 4                R
# ..             ...
# 974             PG
# ...

# %%
film.iloc[0,0:3]
# Out:
# Star_rating                            9.3
# Title             The Shawshank Redemption
# Content_rating                           R
# Name: 0, dtype: object

# %%
film.iloc[0:5,0:3]
# Out:
#    Star_rating                     Title Content_rating
# 0          9.3  The Shawshank Redemption              R
# 1          9.2             The Godfather              R
# 2          9.1    The Godfather: Part II              R
# 3          9.0           The Dark Knight          PG-13
# 4          8.9              Pulp Fiction              R

# %%
film.iloc[0:5,]
# Out:
#    Star_rating                     Title Content_rating   Genre  Duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          Actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
 film.iloc[0:5,:]
# Out:
#    Star_rating                     Title Content_rating   Genre  Duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          Actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
film[(film.Duration>=200)&(film.Genre=="Crime")]
# Out:
#     Star_rating                        Title Content_rating  Genre  Duration  \
# 2           9.1       The Godfather: Part II              R  Crime       200
# 78          8.4  Once Upon a Time in America              R  Crime       229
#
#                                           Actors_list
# 2   [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 78  [u'Robert De Niro', u'James Woods', u'Elizabet...

# %%
film[(film.Duration>=200)|(film.Genre=="Crime")]
# Out:
#      Star_rating                                          Title  \
# 0            9.3                       The Shawshank Redemption
# 1            9.2                                  The Godfather
# 2            9.1                         The Godfather: Part II
# 4            8.9                                   Pulp Fiction
# 7            8.9  The Lord of the Rings: The Return of the King
# ..           ...                                            ...
# 927          7.5                                          Brick
# 931          7.4                                   Mean Streets
# 950          7.4                                          Bound
# 969          7.4                            Law Abiding Citizen
# 978          7.4                                    Wall Street
#
#     Content_rating      Genre  Duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
film[(film.Duration>=200)|(film.Genre=="Crime")|(film.Genre=="Action")]
# Out:
#      Star_rating                                            Title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 963          7.4                                  La Femme Nikita
# 967          7.4                                         The Rock
# 969          7.4                              Law Abiding Citizen
# 976          7.4  Master and Commander: The Far Side of the World
# 978          7.4                                      Wall Street
#
#     Content_rating   Genre  Duration  \
# 0                R   Crime       142
# 1                R   Crime       175
# 2                R   Crime       200
# ...

# %%
film[film.Genre.isin(["Crime","Drama","Action"])]
# Out:
#      Star_rating                                            Title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 970          7.4                                      Wonder Boys
# 972          7.4                                   Blue Valentine
# 973          7.4                            The Cider House Rules
# 976          7.4  Master and Commander: The Far Side of the World
# 978          7.4                                      Wall Street
#
#     Content_rating   Genre  Duration  \
# 0                R   Crime       142
# 1                R   Crime       175
# 2                R   Crime       200
# ...

# %%
film[film.Genre.isin(["Crime","Drama","Action"])]
